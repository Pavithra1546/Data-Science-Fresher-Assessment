# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("tips.csv")

# %%
dataset
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
dataset.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
dataset.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # Box Plot

# %%
#boxplot-means percentile
sb.boxplot(x="smoker",y="total_bill",data=dataset,hue="sex")
plt.show()

# %%
#boxplot-means percentile
sb.boxplot(x="day",y="total_bill",data=dataset,hue="sex")
plt.show()

# %%
#boxplot-means percentile
sb.boxplot(x="time",y="total_bill",data=dataset,hue="sex")
plt.show()

# %%
dataset['total_bill'].plot(kind='box', title='Total bill of people')
plt.show()

# %%
dataset["tip"].plot(kind='box', title='Total bill of people')
plt.show()

# %%
dataset['size'].plot(kind='box', title='Total bill of people')
plt.show()

# %%
sb.scatterplot(x="total_bill",
                    y="tip",
                    data=dataset,hue="smoker")

# %%
sb.scatterplot(x="total_bill",
                    y="tip",
                    data=dataset,hue="sex")
